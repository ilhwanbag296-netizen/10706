# %% [markdown]
# <a href="https://colab.research.google.com/github/ilhwanbag296-netizen/10706/blob/main/20260901.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("안녕안녕하세요")
print("반갑반갑습니다")
print("저는 일환입니다")
# Out:
# 안녕안녕하세요
# 반갑반갑습니다
# 저는 박일환박일박일환입니다
