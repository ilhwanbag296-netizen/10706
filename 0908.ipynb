# %% [markdown]
# <a href="https://colab.research.google.com/github/ilhwanbag296-netizen/10706/blob/main/0908.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('=====회전초밥=====')
print(' 접시 단가 개수 합계')
print('빨간색 1,000 2  2,000')
print('노란색 2,000 3  6,000')
print('파란색 3,000 1  3,000')
print('초록색 4,000 2  8,000')
print('총 가격        19,000')
print('===================')
# Out:
# =====회전초밥=====
#  접시 단가 개수 합계
# 빨간색 1,000 2  2,000
# 노란색 2,000 3  6,000
# 파란색 3,000 1  3,000
# 초록색 4,000 2  8,000
# 총 가격        19,000
# ...
