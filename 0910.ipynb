# %% [markdown]
# <a href="https://colab.research.google.com/github/ilhwanbag296-netizen/10706/blob/main/0910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 'hello'
b= 'world'
print(a+b)
print(a*3)
print(a<b)
print('h' in a)
print('wor' not in b)
# Out:
# helloworld
# hellohellohello
# True
# True
# False

# %%
a= 'Hello Pythan'

print(a[6])
print(a[-1])
# Out:
# H
# P
# n

# %%
a= 'Hello Pythan'
print(a[0:5])
print(a[6:])
print(a[:5])
print(a[6:-4])
print(a[0:9:2])
# Out:
# Hello
# Pythan
# Hello
# Py
# HloPt

# %%
a=input('주민등록번호 입력')
b=a[0:2]
c=a[2:4]
d=a[4:6]
print(f'{b}년 {c}월 {d}일')
# Out:
# 주민등록번호 입력101016
# 10년 10월 16일

# %%
a=input()
print(a[::-1])
