# %% [markdown]
# <a href="https://colab.research.google.com/github/ilhwanbag296-netizen/10706/blob/main/0922.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a={}
b={88: 'seoul',24: 'paris', 'num':[10,20]}
c= {'name': 'kim', 'name': 'lee'}
print(a,type(a))
print(len(b))
print(b[88])
print(c['name'])
# Out:
# {} <class 'dict'>
# 3
# seoul
# lee

# %%
a={88: 'london', 20: 'tokyo'}
a[88]='seoul'
a[24]= 'paris'
del a[20]
a.update({24: 'busan'})
a.update({30: 'suwon'})
print(a)
# Out:
# {88: 'seoul', 24: 'busan', 30: 'suwon'}

# %%
print(dic.values())
print(sorted(dic.values()))
# Out:
# dict_values(['포도', '사과'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_607/1293381597.py in <cell line: 0>()
#       1 print(dic.values())
# ----> 2 print(sorted(dic.values))
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
print(dic.items())

# %%
p=dic.pop('apple')
print(p)
print(dic)

# %%
print(dic.get('grape'))
print(dic.get('apple'))
print(dic.get('apple','없음'))

# %%
print

# %%
dic = {'grape' : '포도', 'apple' : '사과'}
print(dic)
print(sorted(dic))
print(sorted(dic,reverse=True))
print(sorted(dic.items()))
print('apple' in dic)
print(dic.get('apple','gg'))
# Out:
# {'=grape': '포도', 'apple': '사과'}
# ['=grape', 'apple']
# ['apple', '=grape']
# [('=grape', '포도'), ('apple', '사과')]
# True
# 사과

# %%
menu = {'burger': '5000' , 'pizza' : '8000', 'pasta' : '7000' }
print(menu)
menu['pizza']=8500
menu['chicken']=10000
del menu['pasta']
print(menu)
print('가격역순정렬:', sorted(menu. values(), reverse=True))
# Out:
# {'burger': '5000', 'pizza': '8000', 'pasta': '7000'}
# {'burger': '5000', 'pizza': 8500, 'chicken': 10000}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_607/1783950774.py in <cell line: 0>()
#       5 del menu['pasta']
#       6 print(menu)
# ----> 7 print('가격역순정렬:', sorted(menu. values(), reverse=True))
#       8
#
# TypeError: '<' not supported between instances of 'str' and 'int'
